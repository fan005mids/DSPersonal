# %%
# Crawl


import requests
from bs4 import BeautifulSoup

url = 'https://the-turing-way.netlify.app/index.html'

reqs = requests.get(url)

soup = BeautifulSoup(reqs.text, 'html.parser')

urls = []
for link in soup.find_all('a'):
    urls.append(link.get('href'))
urls
# Out:
# ['#',
#  '#',
#  'reproducible-research/reproducible-research.html',
#  'reproducible-research/overview.html',
#  'reproducible-research/overview/overview-definitions.html',
#  'reproducible-research/overview/overview-benefit.html',
#  'reproducible-research/overview/overview-barriers.html',
#  'reproducible-research/overview/overview-resources.html',
#  'reproducible-research/open.html',
#  'reproducible-research/open/open-data.html',
#  'reproducible-research/open/open-source.html',
#  'reproducible-research/open/open-hardware.html',
#  'reproducible-research/open/open-access.html',
#  'reproducible-research/open/open-notebooks.html',
#  'reproducible-research/open/open-scholarship.html',
#  'reproducible-research/open/open-checklist.html',
#  'reproducible-research/open/open-resources.html',
#  'reproducible-research/vcs.html',
#  'reproducible-research/vcs/vcs-workflow.html',
#  'reproducible-research/vcs/vcs-git.html',
#  'reproducible-research/vcs/vcs-git-commit.html',
#  'reproducible-research/vcs/vcs-git-compare.html',
#  'reproducible-research/vcs/vcs-git-branches.html',
#  'reproducible-research/vcs/vcs-git-merge.html',
#  'reproducible-research/vcs/vcs-git-interactive.html',
#  'reproducible-research/vcs/vcs-github.html',
#  'reproducible-research/vcs/vcs-git-summary.html',
#  'reproducible-research/vcs/vcs-data.html',
#  'reproducible-research/vcs/vcs-personal-stories.html',
#  'reproducible-research/vcs/vcs-checklist.html',
#  'reproducible-research/vcs/vcs-resources.html',
#  'reproducible-research/licensing.html',
#  'reproducible-research/licensing/licensing-software.html',
#  'reproducible-research/licensing/licensing-data.html',
#  'reproducible-research/licensing/licensing-ml.html',
#  'reproducible-research/licensing/licensing-ml-case-studies.html',
#  'reproducible-research/licensing/licensing-compatibility.html',
#  'reproducible-research/licensing/licensing-checklist.html',
#  'reproducible-research/rdm.html',
#  'reproducible-research/rdm/rdm-data.html',
#  'reproducible-research/rdm/rdm-dmp.html',
#  'reproducible-research/rdm/rdm-fair.html',
#  'reproducible-research/rdm/rdm-personal.html',
#  'reproducible-research/rdm/rdm-storage.html',
#  'reproducible-research/rdm/rdm-spreadsheets.html',
#  'reproducible-research/rdm/rdm-metadata.html',
#  'reproducible-research/rdm/rdm-data-curation.html',
#  'reproducible-research/rdm/rdm-sharing.html',
#  'reproducible-research/rdm/rdm-article.html',
#  'reproducible-research/rdm/rdm-toolkits.html',
#  'reproducible-research/rdm/rdm-stories.html',
#  'reproducible-research/rdm/rdm-checklist.html',
#  'reproducible-research/rdm/rdm-resources.html',
#  'reproducible-research/renv.html',
#  'reproducible-research/renv/renv-options.html',
#  'reproducible-research/renv/renv-package.html',
#  'reproducible-research/renv/renv-yaml.html',
#  'reproducible-research/renv/renv-virtualmachine.html',
#  'reproducible-research/renv/renv-containers.html',
#  'reproducible-research/renv/renv-resources.html',
#  'reproducible-research/binderhub.html',
#  'reproducible-research/binderhub/binderhub-introduction.html',
#  'reproducible-research/binderhub/binderhub-compute.html',
#  'reproducible-research/binderhub/binderhub-build.html',
#  'reproducible-research/binderhub/binderhub-resources.html',
#  'reproducible-research/code-quality.html',
#  'reproducible-research/code-quality/code-quality-style.html',
#  'reproducible-research/code-quality/code-quality-resources.html',
#  'reproducible-research/testing.html',
#  'reproducible-research/testing/testing-guidance.html',
#  'reproducible-research/testing/testing-overview.html',
#  'reproducible-research/testing/testing-smoketest.html',
#  'reproducible-research/testing/testing-unittest.html',
#  'reproducible-research/testing/testing-integrationtest.html',
#  'reproducible-research/testing/testing-systemtest.html',
#  'reproducible-research/testing/testing-acceptance-regression.html',
#  'reproducible-research/testing/testing-runtime.html',
#  'reproducible-research/testing/testing-driven-development.html',
#  'reproducible-research/testing/testing-exceptions.html',
#  'reproducible-research/testing/testing-checklist.html',
#  'reproducible-research/testing/testing-resources.html',
#  'reproducible-research/reviewing.html',
#  'reproducible-research/reviewing/reviewing-motivation.html',
#  'reproducible-research/reviewing/reviewing-recommend.html',
#  'reproducible-research/reviewing/reviewing-workflow.html',
#  'reproducible-research/reviewing/reviewing-checklist.html',
#  'reproducible-research/reviewing/reviewing-resources.html',
#  'reproducible-research/code-reuse.html',
#  'reproducible-research/code-reuse/code-reuse-overview.html',
#  'reproducible-research/code-reuse/code-reuse-details.html',
#  'reproducible-research/ci.html',
#  'reproducible-research/ci/ci-options.html',
#  'reproducible-research/ci/ci-github-actions.html',
#  'reproducible-research/ci/ci-building-gh-actions.html',
#  'reproducible-research/ci/ci-practices.html',
#  'reproducible-research/ci/ci-resources.html',
#  'reproducible-research/make.html',
#  'reproducible-research/make/make-examples.html',
#  'reproducible-research/make/make-debugging.html',
#  'reproducible-research/make/make-casestudy.html',
#  'reproducible-research/make/make-results.html',
#  'reproducible-research/make/make-resources.html',
#  'reproducible-research/make/make-appendix.html',
#  'reproducible-research/compendia.html',
#  'reproducible-research/risk-assess.html',
#  'reproducible-research/risk-assess/risk-assess-impact.html',
#  'reproducible-research/risk-assess/risk-assess-resources.html',
#  'reproducible-research/case-studies.html',
#  'reproducible-research/case-studies/case-study-statistical.html',
#  'project-design/project-design.html',
#  'project-design/pd-overview.html',
#  'project-design/pd-overview/pd-overview-planning.html',
#  'project-design/pd-overview/pd-overview-repro.html',
#  'project-design/pd-overview/pd-overview-methods.html',
#  'project-design/pd-overview/pd-overview-version.html',
#  'project-design/pd-overview/pd-overview-sharing.html',
#  'project-design/project-repo.html',
#  'project-design/project-repo/project-repo-readme.html',
#  'project-design/project-repo/project-repo-roadmapping.html',
#  'project-design/project-repo/project-repo-contributors.html',
#  'project-design/project-repo/project-repo-participation.html',
#  'project-design/project-repo/project-repo-advanced.html',
#  'project-design/project-repo/project-repo-resources.html',
#  'project-design/persona.html',
#  'project-design/persona/persona-creation.html',
#  'project-design/persona/persona-contributors.html',
#  'project-design/filenaming.html',
#  'project-design/code-styling.html',
#  'project-design/code-styling/code-styling-guidelines.html',
#  'project-design/code-styling/code-styling-readability.html',
#  'project-design/code-styling/code-styling-tools.html',
#  'project-design/sdp.html',
#  'project-design/sdp/types.html',
#  'project-design/sdp/personal.html',
#  'project-design/sdp/confidential.html',
#  'project-design/sdp/biological.html',
#  'project-design/sdp/metadata.html',
#  'project-design/sdp/combined.html',
#  'project-design/sdpm.html',
#  'project-design/sdpm/informed.html',
#  'project-design/sdpm/data-privacy-strategies.html',
#  'project-design/sdpm/sharing-sensitive-data.html',
#  'project-design/sdpm/resources.html',
#  'project-design/sdpw.html',
#  'project-design/sdpw/trew.html',
#  'project-design/sdpw/pd-sdp-private-learning.html',
#  'project-design/sdpw/pd-sdp-sensitive-files.html',
#  'project-design/sdpw/pd-sdp-sensitive-code.html',
#  'project-design/sdpw/pd-sdp-exposing-data.html',
#  'project-design/sdpw/pd-sdp-resources.html',
#  'project-design/data-governance.html',
#  'project-design/data-governance/data-gov-ml.html',
#  'communication/communication.html',
#  'communication/comms-overview.html',
#  'communication/comms-overview/comms-overview-principles.html',
#  'communication/comms-overview/comms-overview-accessibly.html',
#  'communication/comms-overview/comms-overview-resources.html',
#  'communication/open.html',
#  'communication/open/education.html',
#  'communication/blogs.html',
#  'communication/blogs/blogs-webpage.html',
#  'communication/blogs/blogs-personal-stories.html',
#  'communication/lay-summaries.html',
#  'communication/lay-summaries/lay-summaries-personal-stories.html',
#  'communication/podcasts.html',
#  'communication/podcasts/podcasts-personal-stories.html',
#  'communication/presentations.html',
#  'communication/presentations/presentations-remote.html',
#  'communication/presentations/presentations-personal-stories.html',
#  'communication/social-media.html',
#  'communication/social-media/social-media-twitter-tips.html',
#  'communication/social-media/social-media-twitter-multiple.html',
#  'communication/research-objects.html',
#  'communication/research-objects/ro-concepts.html',
#  'communication/research-objects/ro-implementation.html',
#  'communication/citable.html',
#  'communication/citable/citable-steps.html',
#  'communication/citable/citable-cite.html',
#  'communication/citable/citable-cff.html',
#  'communication/citable/citable-cffinit.html',
#  'communication/citable/citable-linking.html',
#  'communication/citable/citable-orcid.html',
#  'communication/citable/citable-resources.html',
#  'communication/dif-articles.html',
#  'communication/dif-articles/data.html',
#  'communication/dif-articles/methods.html',
#  'communication/dif-articles/micro.html',
#  'communication/dif-articles/reg.html',
#  'communication/dif-articles/software.html',
#  'communication/os-comms.html',
#  'communication/os-comms/os-comms-issue-tracking.html',
#  'communication/os-comms/os-comms-channels.html',
#  'communication/aa.html',
#  'communication/aa/aa-overview.html',
#  'communication/aa/aa-misconduct.html',
#  'communication/aa/aa-traditions.html',
#  'communication/aa/aa-equitable.html',
#  'communication/aa/aa-tips.html',
#  'communication/aa/aa-stories-interdisciplinary.html',
#  'communication/aa/aa-stories-community.html',
#  'communication/aa/aa-resources.html',
#  'communication/peer-review.html',
#  'communication/peer-review/peer-review-overview.html',
#  'communication/peer-review/peer-review-open.html',
#  'communication/peer-review/peer-review-guidance.html',
#  'communication/peer-review/peer-review-code.html',
#  'communication/peer-review/peer-review-resources.html',
#  'communication/binder.html',
#  'communication/binder/zero-to-binder.html',
#  'collaboration/collaboration.html',
#  'collaboration/github-novice.html',
#  'collaboration/github-novice/github-novice-motivation.html',
#  'collaboration/github-novice/github-novice-firststeps.html',
#  'collaboration/github-novice/github-novice-features.html',
#  'collaboration/github-novice/github-novice-advanced.html',
#  'collaboration/maintain-review.html',
#  'collaboration/maintain-review/maintain-review-maintenance.html',
#  'collaboration/maintain-review/maintain-review-permissions.html',
#  'collaboration/maintain-review/maintain-review-review.html',
#  'collaboration/maintain-review/maintain-review-merge.html',
#  'collaboration/maintain-review/maintain-review-resources.html',
#  'collaboration/organising-meetings.html',
#  'collaboration/coworking.html',
#  'collaboration/organising-conference.html',
#  'collaboration/chairing.html',
#  'collaboration/event-participation.html',
#  'collaboration/informal-chats.html',
#  'collaboration/event-tools.html',
#  'collaboration/stakeholder-engagement.html',
#  'collaboration/new-community.html',
#  'collaboration/new-community/new-community-guide.html',
#  'collaboration/new-community/new-community-techissues.html',
#  'collaboration/new-community/new-community-differences.html',
#  'collaboration/new-community/new-community-teamwork.html',
#  'collaboration/academic-industry.html',
#  'collaboration/academic-industry/academic-industry-establish.html',
#  'collaboration/academic-industry/academic-industry-community.html',
#  'collaboration/academic-industry/academic-industry-personal-story.html',
#  'collaboration/team-manual.html',
#  'collaboration/leadership.html',
#  'collaboration/leadership/leadership-features.html',
#  'collaboration/leadership/leadership-building.html',
#  'collaboration/leadership/leadership-opportunities.html',
#  'collaboration/leadership/leadership-story-hackathon.html',
#  'collaboration/leadership/leadership-story-data-librarian.html',
#  'collaboration/research-infrastructure-roles.html',
#  'collaboration/research-infrastructure-roles/community-manager.html',
#  'collaboration/research-infrastructure-roles/data-steward.html',
#  'collaboration/research-infrastructure-roles/data-steward-personal-story.html',
#  'collaboration/research-infrastructure-roles/data-wrangler.html',
#  'collaboration/research-infrastructure-roles/rse.html',
#  'collaboration/research-infrastructure-roles/rse-personal-story.html',
#  'collaboration/research-infrastructure-roles/ram.html',
#  'collaboration/research-infrastructure-roles/research-infrastructure-developer.html',
#  'collaboration/remote-collab.html',
#  'collaboration/remote-collab/remote-collab-prosandcons.html',
#  'collaboration/remote-collab/remote-collab-guidelines.html',
#  'collaboration/remote-collab/remote-collab-team.html',
#  'collaboration/remote-collab/remote-collab-useful-resources.html',
#  'collaboration/hybrid-collab.html',
#  'collaboration/hybrid-collab/hybrid-collab-challenges.html',
#  'collaboration/hybrid-collab/hybrid-collab-guidelines.html',
#  'collaboration/hybrid-collab/hybrid-collab-resources.html',
#  'collaboration/shared-ownership.html',
#  'collaboration/shared-ownership/shared-ownership-projects.html',
#  'collaboration/shared-ownership/shared-ownership-models.html',
#  'collaboration/shared-ownership/shared-ownership-challenges.html',
#  'collaboration/shared-ownership/shared-ownership-defaults.html',
#  'collaboration/oss-sustainability/oss-sustainability-challenges.html',
#  'ethical-research/ethical-research.html',
#  'ethical-research/ethics-intro.html',
#  'ethical-research/ethics-committees.html',
#  'ethical-research/preclinical-research.html',
#  'ethical-research/law-policy.html',
#  'ethical-research/law-policy/law-policy-ethics.html',
#  'ethical-research/law-policy/law-policy-rights.html',
#  'ethical-research/law-policy/law-policy-resources.html',
#  'ethical-research/social-data.html',
#  'ethical-research/activism.html',
#  'ethical-research/activism/activism-unionisation.html',
#  'ethical-research/activism/activism-whistleblowing.html',
#  'ethical-research/activism/activism-cultural-change.html',
#  'ethical-research/activism/activism-robodebt.html',
#  'ethical-research/activism/activism-case-study-google.html',
#  'ethical-research/internal-policy.html',
#  'ethical-research/self-reflection.html',
#  'ethical-research/self-reflection/sr-positionality.html',
#  'ethical-research/self-reflection/sr-power.html',
#  'ethical-research/self-reflection/sr-prompts.html',
#  'ethical-research/self-reflection/sr-resources.html',
#  'ethical-research/ethics-open-source-governance.html',
#  'community-handbook/community-handbook.html',
#  'community-handbook/coc.html',
#  'community-handbook/coc/coc-details.html',
#  'community-handbook/coc/coc-reporting.html',
#  'community-handbook/coc/coc-enforcement.html',
#  'community-handbook/coc/coc-acknowledgement.html',
#  'community-handbook/style.html',
#  'community-handbook/style/style-citing.html',
#  'community-handbook/style/style-crossref.html',
#  'community-handbook/style/style-figures.html',
#  'community-handbook/style/style-more-styling.html',
#  'community-handbook/style/style-custom-styling.html',
#  'community-handbook/consistency.html',
#  'community-handbook/consistency/consistency-formatting.html',
#  'community-handbook/consistency/consistency-structure.html',
#  'community-handbook/consistency/consistency-language.html',
#  'community-handbook/local-build.html',
#  'community-handbook/contributing.html',
#  'community-handbook/contributing/contributing-templates.html',
#  'community-handbook/contributing/contributing-workflow.html',
#  'community-handbook/acknowledgement.html',
#  'community-handbook/acknowledgement/acknowledgement-members.html',
#  'community-handbook/acknowledgement/acknowledgement-record.html',
#  'community-handbook/acknowledgement/acknowledgement-examples.html',
#  'community-handbook/newsletters.html',
#  'community-handbook/newsletters/newsletters-process.html',
#  'community-handbook/newsletters/newsletters-style.html',
#  'community-handbook/newsletters/newsletters-template.html',
#  'community-handbook/bookdash.html',
#  'community-handbook/bookdash/bookdash-application.html',
#  'community-handbook/bookdash/bookdash-logistics.html',
#  'community-handbook/bookdash/bookdash-illustrator.html',
#  'community-handbook/bookdash/bookdash-selection.html',
#  'community-handbook/bookdash/bookdash-events.html',
#  'community-handbook/bookdash/bookdash-after.html',
#  'community-handbook/coworking.html',
#  'community-handbook/coworking/coworking-motivation.html',
#  'community-handbook/coworking/coworking-collabcafe.html',
#  'community-handbook/coworking/coworking-weekly.html',
#  'community-handbook/coworking/coworking-organisation.html',
#  'community-handbook/fireside-chat.html',
#  'community-handbook/fireside-chat/fireside-chat-checklist.html',
#  'community-handbook/fireside-chat/fireside-chat-roles.html',
#  'community-handbook/presenting.html',
#  'community-handbook/templates.html',
#  'community-handbook/templates/template-bookdash-index.html',
#  'community-handbook/templates/template-bookdash-precall.html',
#  'community-handbook/templates/template-bookdash-github.html',
#  'community-handbook/templates/template-bookdash-notes.html',
#  'community-handbook/templates/template-bookdash-feedback.html',
#  'community-handbook/templates/template-coworking-collabcafe.html',
#  'community-handbook/templates/template-coworking-weekly.html',
#  'community-handbook/templates/template-newsletter-draft.html',
#  'community-handbook/templates/template-fireside-chat.html',
#  'community-handbook/translation.html',
#  'community-handbook/translation/translation-localisation.html',
#  'community-handbook/translation/translation-workflow.html',
#  'community-handbook/translation/translation-getting-started.html',
#  'community-handbook/translation/translation-hello-crowdin.html',
#  'afterword/afterword.html',
#  'afterword/legal-disclaimer.html',
#  'afterword/glossary.html',
#  'afterword/bibliography.html',
#  'afterword/contributors-record.html',
#  'https://github.com/alan-turing-institute/the-turing-way',
#  'https://jupyterbook.org',
#  'https://github.com/alan-turing-institute/the-turing-way',
#  'https://github.com/alan-turing-institute/the-turing-way/issues/new?title=Issue%20on%20page%20%2Findex.html&body=Your%20issue%20content%20here.',
#  'https://github.com/alan-turing-institute/the-turing-way/edit/main/book/website/index.md',
#  '_sources/index.md',
#  '#our-community',
#  '#history',
#  '#citing-the-turing-way',
#  '#our-community',
#  '#history',
#  '#citing-the-turing-way',
#  '#welcome',
#  'https://github.com/alan-turing-institute/the-turing-way',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/CONTRIBUTING.md',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/LICENSE.md',
#  'https://join.slack.com/t/theturingway/shared_invite/zt-fn608gvb-h_ZSpoA29cCdUwR~TIqpBw',
#  'http://doi.org/10.5281/zenodo.3332807',
#  '#welcome-image',
#  '#our-community',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/LICENSE.md',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/CONTRIBUTING.md',
#  'https://github.com/alan-turing-institute/the-turing-way#get-in-touch',
#  'community-handbook/community-handbook.html#ch',
#  'http://doi.org/10.5281/zenodo.3695300',
#  '#theturingway-chapters',
#  'https://www.turing.ac.uk/',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/CODE_OF_CONDUCT.md',
#  '#history',
#  'reproducible-research/vcs.html#rr-vcs',
#  'reproducible-research/testing.html#rr-testing',
#  'reproducible-research/ci.html#rr-ci',
#  'reproducible-research/reproducible-research.html#rr',
#  'project-design/project-design.html#pd',
#  'communication/communication.html#cm',
#  'collaboration/collaboration.html#cl',
#  'ethical-research/ethical-research.html#er',
#  '#citing-the-turing-way',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/LICENSE.md',
#  'https://doi.org/10.5281/zenodo.3233853',
#  'http://doi.org/10.5281/zenodo.3233986',
#  'https://doi.org/10.5281/zenodo.3233853',
#  'reproducible-research/overview/overview-definitions.html#rr-overview-definitions',
#  'http://web.archive.org',
#  'https://web.archive.org/web/20191030093753/https://the-turing-way.netlify.com/reproducibility/03/definitions.html',
#  'https://github.com/alan-turing-institute/the-turing-way#get-in-touch',
#  'reproducible-research/reproducible-research.html',
#  'https://github.com/alan-turing-institute/the-turing-way/blob/main/LICENSE.md']

# %%
import re
urls_filtered_list = []
for u in urls:
    for i in re.findall('.+html', str(u)):
        url_to_be_appended = "https://the-turing-way.netlify.app/"+i
        if url_to_be_appended not in urls_filtered_list:
            print(i)
            urls_filtered_list.append(url_to_be_appended)

urls_filtered_list = urls_filtered_list[:-2]
urls_filtered_list.insert(0, 'https://the-turing-way.netlify.app/index.html')
# Out:
# reproducible-research/reproducible-research.html
# reproducible-research/overview.html
# reproducible-research/overview/overview-definitions.html
# reproducible-research/overview/overview-benefit.html
# reproducible-research/overview/overview-barriers.html
# reproducible-research/overview/overview-resources.html
# reproducible-research/open.html
# reproducible-research/open/open-data.html
# reproducible-research/open/open-source.html
# reproducible-research/open/open-hardware.html
# reproducible-research/open/open-access.html
# reproducible-research/open/open-notebooks.html
# reproducible-research/open/open-scholarship.html
# reproducible-research/open/open-checklist.html
# reproducible-research/open/open-resources.html
# reproducible-research/vcs.html
# reproducible-research/vcs/vcs-workflow.html
# reproducible-research/vcs/vcs-git.html
# reproducible-research/vcs/vcs-git-commit.html
# reproducible-research/vcs/vcs-git-compare.html
# reproducible-research/vcs/vcs-git-branches.html
# reproducible-research/vcs/vcs-git-merge.html
# reproducible-research/vcs/vcs-git-interactive.html
# reproducible-research/vcs/vcs-github.html
# reproducible-research/vcs/vcs-git-summary.html
# reproducible-research/vcs/vcs-data.html
# reproducible-research/vcs/vcs-personal-stories.html
# reproducible-research/vcs/vcs-checklist.html
# reproducible-research/vcs/vcs-resources.html
# reproducible-research/licensing.html
# reproducible-research/licensing/licensing-software.html
# reproducible-research/licensing/licensing-data.html
# reproducible-research/licensing/licensing-ml.html
# reproducible-research/licensing/licensing-ml-case-studies.html
# reproducible-research/licensing/licensing-compatibility.html
# reproducible-research/licensing/licensing-checklist.html
# reproducible-research/rdm.html
# reproducible-research/rdm/rdm-data.html
# reproducible-research/rdm/rdm-dmp.html
# reproducible-research/rdm/rdm-fair.html
# reproducible-research/rdm/rdm-personal.html
# reproducible-research/rdm/rdm-storage.html
# reproducible-research/rdm/rdm-spreadsheets.html
# reproducible-research/rdm/rdm-metadata.html
# reproducible-research/rdm/rdm-data-curation.html
# reproducible-research/rdm/rdm-sharing.html
# reproducible-research/rdm/rdm-article.html
# reproducible-research/rdm/rdm-toolkits.html
# reproducible-research/rdm/rdm-stories.html
# reproducible-research/rdm/rdm-checklist.html
# reproducible-research/rdm/rdm-resources.html
# reproducible-research/renv.html
# reproducible-research/renv/renv-options.html
# reproducible-research/renv/renv-package.html
# reproducible-research/renv/renv-yaml.html
# reproducible-research/renv/renv-virtualmachine.html
# reproducible-research/renv/renv-containers.html
# reproducible-research/renv/renv-resources.html
# reproducible-research/binderhub.html
# reproducible-research/binderhub/binderhub-introduction.html
# reproducible-research/binderhub/binderhub-compute.html
# reproducible-research/binderhub/binderhub-build.html
# reproducible-research/binderhub/binderhub-resources.html
# reproducible-research/code-quality.html
# reproducible-research/code-quality/code-quality-style.html
# reproducible-research/code-quality/code-quality-resources.html
# reproducible-research/testing.html
# reproducible-research/testing/testing-guidance.html
# reproducible-research/testing/testing-overview.html
# reproducible-research/testing/testing-smoketest.html
# reproducible-research/testing/testing-unittest.html
# reproducible-research/testing/testing-integrationtest.html
# reproducible-research/testing/testing-systemtest.html
# reproducible-research/testing/testing-acceptance-regression.html
# reproducible-research/testing/testing-runtime.html
# reproducible-research/testing/testing-driven-development.html
# reproducible-research/testing/testing-exceptions.html
# reproducible-research/testing/testing-checklist.html
# reproducible-research/testing/testing-resources.html
# reproducible-research/reviewing.html
# reproducible-research/reviewing/reviewing-motivation.html
# reproducible-research/reviewing/reviewing-recommend.html
# reproducible-research/reviewing/reviewing-workflow.html
# reproducible-research/reviewing/reviewing-checklist.html
# reproducible-research/reviewing/reviewing-resources.html
# reproducible-research/code-reuse.html
# reproducible-research/code-reuse/code-reuse-overview.html
# reproducible-research/code-reuse/code-reuse-details.html
# reproducible-research/ci.html
# reproducible-research/ci/ci-options.html
# reproducible-research/ci/ci-github-actions.html
# reproducible-research/ci/ci-building-gh-actions.html
# reproducible-research/ci/ci-practices.html
# reproducible-research/ci/ci-resources.html
# reproducible-research/make.html
# reproducible-research/make/make-examples.html
# reproducible-research/make/make-debugging.html
# reproducible-research/make/make-casestudy.html
# reproducible-research/make/make-results.html
# reproducible-research/make/make-resources.html
# reproducible-research/make/make-appendix.html
# reproducible-research/compendia.html
# reproducible-research/risk-assess.html
# reproducible-research/risk-assess/risk-assess-impact.html
# reproducible-research/risk-assess/risk-assess-resources.html
# reproducible-research/case-studies.html
# reproducible-research/case-studies/case-study-statistical.html
# project-design/project-design.html
# project-design/pd-overview.html
# project-design/pd-overview/pd-overview-planning.html
# project-design/pd-overview/pd-overview-repro.html
# project-design/pd-overview/pd-overview-methods.html
# project-design/pd-overview/pd-overview-version.html
# project-design/pd-overview/pd-overview-sharing.html
# project-design/project-repo.html
# project-design/project-repo/project-repo-readme.html
# project-design/project-repo/project-repo-roadmapping.html
# project-design/project-repo/project-repo-contributors.html
# project-design/project-repo/project-repo-participation.html
# project-design/project-repo/project-repo-advanced.html
# project-design/project-repo/project-repo-resources.html
# project-design/persona.html
# project-design/persona/persona-creation.html
# project-design/persona/persona-contributors.html
# project-design/filenaming.html
# project-design/code-styling.html
# project-design/code-styling/code-styling-guidelines.html
# project-design/code-styling/code-styling-readability.html
# project-design/code-styling/code-styling-tools.html
# project-design/sdp.html
# project-design/sdp/types.html
# project-design/sdp/personal.html
# project-design/sdp/confidential.html
# project-design/sdp/biological.html
# project-design/sdp/metadata.html
# project-design/sdp/combined.html
# project-design/sdpm.html
# project-design/sdpm/informed.html
# project-design/sdpm/data-privacy-strategies.html
# project-design/sdpm/sharing-sensitive-data.html
# project-design/sdpm/resources.html
# project-design/sdpw.html
# project-design/sdpw/trew.html
# project-design/sdpw/pd-sdp-private-learning.html
# project-design/sdpw/pd-sdp-sensitive-files.html
# project-design/sdpw/pd-sdp-sensitive-code.html
# project-design/sdpw/pd-sdp-exposing-data.html
# project-design/sdpw/pd-sdp-resources.html
# project-design/data-governance.html
# project-design/data-governance/data-gov-ml.html
# communication/communication.html
# communication/comms-overview.html
# communication/comms-overview/comms-overview-principles.html
# communication/comms-overview/comms-overview-accessibly.html
# communication/comms-overview/comms-overview-resources.html
# communication/open.html
# communication/open/education.html
# communication/blogs.html
# communication/blogs/blogs-webpage.html
# communication/blogs/blogs-personal-stories.html
# communication/lay-summaries.html
# communication/lay-summaries/lay-summaries-personal-stories.html
# communication/podcasts.html
# communication/podcasts/podcasts-personal-stories.html
# communication/presentations.html
# communication/presentations/presentations-remote.html
# communication/presentations/presentations-personal-stories.html
# communication/social-media.html
# communication/social-media/social-media-twitter-tips.html
# communication/social-media/social-media-twitter-multiple.html
# communication/research-objects.html
# communication/research-objects/ro-concepts.html
# communication/research-objects/ro-implementation.html
# communication/citable.html
# communication/citable/citable-steps.html
# communication/citable/citable-cite.html
# communication/citable/citable-cff.html
# communication/citable/citable-cffinit.html
# communication/citable/citable-linking.html
# communication/citable/citable-orcid.html
# communication/citable/citable-resources.html
# communication/dif-articles.html
# communication/dif-articles/data.html
# communication/dif-articles/methods.html
# communication/dif-articles/micro.html
# communication/dif-articles/reg.html
# communication/dif-articles/software.html
# communication/os-comms.html
# communication/os-comms/os-comms-issue-tracking.html
# communication/os-comms/os-comms-channels.html
# communication/aa.html
# communication/aa/aa-overview.html
# communication/aa/aa-misconduct.html
# communication/aa/aa-traditions.html
# communication/aa/aa-equitable.html
# communication/aa/aa-tips.html
# communication/aa/aa-stories-interdisciplinary.html
# communication/aa/aa-stories-community.html
# communication/aa/aa-resources.html
# communication/peer-review.html
# communication/peer-review/peer-review-overview.html
# communication/peer-review/peer-review-open.html
# communication/peer-review/peer-review-guidance.html
# communication/peer-review/peer-review-code.html
# communication/peer-review/peer-review-resources.html
# communication/binder.html
# communication/binder/zero-to-binder.html
# collaboration/collaboration.html
# collaboration/github-novice.html
# collaboration/github-novice/github-novice-motivation.html
# collaboration/github-novice/github-novice-firststeps.html
# collaboration/github-novice/github-novice-features.html
# collaboration/github-novice/github-novice-advanced.html
# collaboration/maintain-review.html
# collaboration/maintain-review/maintain-review-maintenance.html
# collaboration/maintain-review/maintain-review-permissions.html
# collaboration/maintain-review/maintain-review-review.html
# collaboration/maintain-review/maintain-review-merge.html
# collaboration/maintain-review/maintain-review-resources.html
# collaboration/organising-meetings.html
# collaboration/coworking.html
# collaboration/organising-conference.html
# collaboration/chairing.html
# collaboration/event-participation.html
# collaboration/informal-chats.html
# collaboration/event-tools.html
# collaboration/stakeholder-engagement.html
# collaboration/new-community.html
# collaboration/new-community/new-community-guide.html
# collaboration/new-community/new-community-techissues.html
# collaboration/new-community/new-community-differences.html
# collaboration/new-community/new-community-teamwork.html
# collaboration/academic-industry.html
# collaboration/academic-industry/academic-industry-establish.html
# collaboration/academic-industry/academic-industry-community.html
# collaboration/academic-industry/academic-industry-personal-story.html
# collaboration/team-manual.html
# collaboration/leadership.html
# collaboration/leadership/leadership-features.html
# collaboration/leadership/leadership-building.html
# collaboration/leadership/leadership-opportunities.html
# collaboration/leadership/leadership-story-hackathon.html
# collaboration/leadership/leadership-story-data-librarian.html
# collaboration/research-infrastructure-roles.html
# collaboration/research-infrastructure-roles/community-manager.html
# collaboration/research-infrastructure-roles/data-steward.html
# collaboration/research-infrastructure-roles/data-steward-personal-story.html
# collaboration/research-infrastructure-roles/data-wrangler.html
# collaboration/research-infrastructure-roles/rse.html
# collaboration/research-infrastructure-roles/rse-personal-story.html
# collaboration/research-infrastructure-roles/ram.html
# collaboration/research-infrastructure-roles/research-infrastructure-developer.html
# collaboration/remote-collab.html
# collaboration/remote-collab/remote-collab-prosandcons.html
# collaboration/remote-collab/remote-collab-guidelines.html
# collaboration/remote-collab/remote-collab-team.html
# collaboration/remote-collab/remote-collab-useful-resources.html
# collaboration/hybrid-collab.html
# collaboration/hybrid-collab/hybrid-collab-challenges.html
# collaboration/hybrid-collab/hybrid-collab-guidelines.html
# collaboration/hybrid-collab/hybrid-collab-resources.html
# collaboration/shared-ownership.html
# collaboration/shared-ownership/shared-ownership-projects.html
# collaboration/shared-ownership/shared-ownership-models.html
# collaboration/shared-ownership/shared-ownership-challenges.html
# collaboration/shared-ownership/shared-ownership-defaults.html
# collaboration/oss-sustainability/oss-sustainability-challenges.html
# ethical-research/ethical-research.html
# ethical-research/ethics-intro.html
# ethical-research/ethics-committees.html
# ethical-research/preclinical-research.html
# ethical-research/law-policy.html
# ethical-research/law-policy/law-policy-ethics.html
# ethical-research/law-policy/law-policy-rights.html
# ethical-research/law-policy/law-policy-resources.html
# ethical-research/social-data.html
# ethical-research/activism.html
# ethical-research/activism/activism-unionisation.html
# ethical-research/activism/activism-whistleblowing.html
# ethical-research/activism/activism-cultural-change.html
# ethical-research/activism/activism-robodebt.html
# ethical-research/activism/activism-case-study-google.html
# ethical-research/internal-policy.html
# ethical-research/self-reflection.html
# ethical-research/self-reflection/sr-positionality.html
# ethical-research/self-reflection/sr-power.html
# ethical-research/self-reflection/sr-prompts.html
# ethical-research/self-reflection/sr-resources.html
# ethical-research/ethics-open-source-governance.html
# community-handbook/community-handbook.html
# community-handbook/coc.html
# community-handbook/coc/coc-details.html
# community-handbook/coc/coc-reporting.html
# community-handbook/coc/coc-enforcement.html
# community-handbook/coc/coc-acknowledgement.html
# community-handbook/style.html
# community-handbook/style/style-citing.html
# community-handbook/style/style-crossref.html
# community-handbook/style/style-figures.html
# community-handbook/style/style-more-styling.html
# community-handbook/style/style-custom-styling.html
# community-handbook/consistency.html
# community-handbook/consistency/consistency-formatting.html
# community-handbook/consistency/consistency-structure.html
# community-handbook/consistency/consistency-language.html
# community-handbook/local-build.html
# community-handbook/contributing.html
# community-handbook/contributing/contributing-templates.html
# community-handbook/contributing/contributing-workflow.html
# community-handbook/acknowledgement.html
# community-handbook/acknowledgement/acknowledgement-members.html
# community-handbook/acknowledgement/acknowledgement-record.html
# community-handbook/acknowledgement/acknowledgement-examples.html
# community-handbook/newsletters.html
# community-handbook/newsletters/newsletters-process.html
# community-handbook/newsletters/newsletters-style.html
# community-handbook/newsletters/newsletters-template.html
# community-handbook/bookdash.html
# community-handbook/bookdash/bookdash-application.html
# community-handbook/bookdash/bookdash-logistics.html
# community-handbook/bookdash/bookdash-illustrator.html
# community-handbook/bookdash/bookdash-selection.html
# community-handbook/bookdash/bookdash-events.html
# community-handbook/bookdash/bookdash-after.html
# community-handbook/coworking.html
# community-handbook/coworking/coworking-motivation.html
# community-handbook/coworking/coworking-collabcafe.html
# community-handbook/coworking/coworking-weekly.html
# community-handbook/coworking/coworking-organisation.html
# community-handbook/fireside-chat.html
# community-handbook/fireside-chat/fireside-chat-checklist.html
# community-handbook/fireside-chat/fireside-chat-roles.html
# community-handbook/presenting.html
# community-handbook/templates.html
# community-handbook/templates/template-bookdash-index.html
# community-handbook/templates/template-bookdash-precall.html
# community-handbook/templates/template-bookdash-github.html
# community-handbook/templates/template-bookdash-notes.html
# community-handbook/templates/template-bookdash-feedback.html
# community-handbook/templates/template-coworking-collabcafe.html
# community-handbook/templates/template-coworking-weekly.html
# community-handbook/templates/template-newsletter-draft.html
# community-handbook/templates/template-fireside-chat.html
# community-handbook/translation.html
# community-handbook/translation/translation-localisation.html
# community-handbook/translation/translation-workflow.html
# community-handbook/translation/translation-getting-started.html
# community-handbook/translation/translation-hello-crowdin.html
# afterword/afterword.html
# afterword/legal-disclaimer.html
# afterword/glossary.html
# afterword/bibliography.html
# afterword/contributors-record.html
# https://github.com/alan-turing-institute/the-turing-way/issues/new?title=Issue%20on%20page%20%2Findex.html
# https://web.archive.org/web/20191030093753/https://the-turing-way.netlify.com/reproducibility/03/definitions.html

# %%
urls_filtered_list
# Out:
# ['https://the-turing-way.netlify.app/index.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reproducible-research.html',
#  'https://the-turing-way.netlify.app/reproducible-research/overview.html',
#  'https://the-turing-way.netlify.app/reproducible-research/overview/overview-definitions.html',
#  'https://the-turing-way.netlify.app/reproducible-research/overview/overview-benefit.html',
#  'https://the-turing-way.netlify.app/reproducible-research/overview/overview-barriers.html',
#  'https://the-turing-way.netlify.app/reproducible-research/overview/overview-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-data.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-source.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-hardware.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-access.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-notebooks.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-scholarship.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/open/open-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-workflow.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-commit.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-compare.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-branches.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-merge.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-interactive.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-github.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-git-summary.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-data.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-personal-stories.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/vcs/vcs-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-software.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-data.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-ml.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-ml-case-studies.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-compatibility.html',
#  'https://the-turing-way.netlify.app/reproducible-research/licensing/licensing-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-data.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-dmp.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-fair.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-personal.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-storage.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-spreadsheets.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-metadata.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-data-curation.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-sharing.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-article.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-toolkits.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-stories.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/rdm/rdm-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-options.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-package.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-yaml.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-virtualmachine.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-containers.html',
#  'https://the-turing-way.netlify.app/reproducible-research/renv/renv-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/binderhub.html',
#  'https://the-turing-way.netlify.app/reproducible-research/binderhub/binderhub-introduction.html',
#  'https://the-turing-way.netlify.app/reproducible-research/binderhub/binderhub-compute.html',
#  'https://the-turing-way.netlify.app/reproducible-research/binderhub/binderhub-build.html',
#  'https://the-turing-way.netlify.app/reproducible-research/binderhub/binderhub-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-quality.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-quality/code-quality-style.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-quality/code-quality-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-guidance.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-overview.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-smoketest.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-unittest.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-integrationtest.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-systemtest.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-acceptance-regression.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-runtime.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-driven-development.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-exceptions.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/testing/testing-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing/reviewing-motivation.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing/reviewing-recommend.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing/reviewing-workflow.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing/reviewing-checklist.html',
#  'https://the-turing-way.netlify.app/reproducible-research/reviewing/reviewing-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-reuse.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-reuse/code-reuse-overview.html',
#  'https://the-turing-way.netlify.app/reproducible-research/code-reuse/code-reuse-details.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci/ci-options.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci/ci-github-actions.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci/ci-building-gh-actions.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci/ci-practices.html',
#  'https://the-turing-way.netlify.app/reproducible-research/ci/ci-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-examples.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-debugging.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-casestudy.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-results.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/make/make-appendix.html',
#  'https://the-turing-way.netlify.app/reproducible-research/compendia.html',
#  'https://the-turing-way.netlify.app/reproducible-research/risk-assess.html',
#  'https://the-turing-way.netlify.app/reproducible-research/risk-assess/risk-assess-impact.html',
#  'https://the-turing-way.netlify.app/reproducible-research/risk-assess/risk-assess-resources.html',
#  'https://the-turing-way.netlify.app/reproducible-research/case-studies.html',
#  'https://the-turing-way.netlify.app/reproducible-research/case-studies/case-study-statistical.html',
#  'https://the-turing-way.netlify.app/project-design/project-design.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview/pd-overview-planning.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview/pd-overview-repro.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview/pd-overview-methods.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview/pd-overview-version.html',
#  'https://the-turing-way.netlify.app/project-design/pd-overview/pd-overview-sharing.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-readme.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-roadmapping.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-contributors.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-participation.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-advanced.html',
#  'https://the-turing-way.netlify.app/project-design/project-repo/project-repo-resources.html',
#  'https://the-turing-way.netlify.app/project-design/persona.html',
#  'https://the-turing-way.netlify.app/project-design/persona/persona-creation.html',
#  'https://the-turing-way.netlify.app/project-design/persona/persona-contributors.html',
#  'https://the-turing-way.netlify.app/project-design/filenaming.html',
#  'https://the-turing-way.netlify.app/project-design/code-styling.html',
#  'https://the-turing-way.netlify.app/project-design/code-styling/code-styling-guidelines.html',
#  'https://the-turing-way.netlify.app/project-design/code-styling/code-styling-readability.html',
#  'https://the-turing-way.netlify.app/project-design/code-styling/code-styling-tools.html',
#  'https://the-turing-way.netlify.app/project-design/sdp.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/types.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/personal.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/confidential.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/biological.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/metadata.html',
#  'https://the-turing-way.netlify.app/project-design/sdp/combined.html',
#  'https://the-turing-way.netlify.app/project-design/sdpm.html',
#  'https://the-turing-way.netlify.app/project-design/sdpm/informed.html',
#  'https://the-turing-way.netlify.app/project-design/sdpm/data-privacy-strategies.html',
#  'https://the-turing-way.netlify.app/project-design/sdpm/sharing-sensitive-data.html',
#  'https://the-turing-way.netlify.app/project-design/sdpm/resources.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/trew.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/pd-sdp-private-learning.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/pd-sdp-sensitive-files.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/pd-sdp-sensitive-code.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/pd-sdp-exposing-data.html',
#  'https://the-turing-way.netlify.app/project-design/sdpw/pd-sdp-resources.html',
#  'https://the-turing-way.netlify.app/project-design/data-governance.html',
#  'https://the-turing-way.netlify.app/project-design/data-governance/data-gov-ml.html',
#  'https://the-turing-way.netlify.app/communication/communication.html',
#  'https://the-turing-way.netlify.app/communication/comms-overview.html',
#  'https://the-turing-way.netlify.app/communication/comms-overview/comms-overview-principles.html',
#  'https://the-turing-way.netlify.app/communication/comms-overview/comms-overview-accessibly.html',
#  'https://the-turing-way.netlify.app/communication/comms-overview/comms-overview-resources.html',
#  'https://the-turing-way.netlify.app/communication/open.html',
#  'https://the-turing-way.netlify.app/communication/open/education.html',
#  'https://the-turing-way.netlify.app/communication/blogs.html',
#  'https://the-turing-way.netlify.app/communication/blogs/blogs-webpage.html',
#  'https://the-turing-way.netlify.app/communication/blogs/blogs-personal-stories.html',
#  'https://the-turing-way.netlify.app/communication/lay-summaries.html',
#  'https://the-turing-way.netlify.app/communication/lay-summaries/lay-summaries-personal-stories.html',
#  'https://the-turing-way.netlify.app/communication/podcasts.html',
#  'https://the-turing-way.netlify.app/communication/podcasts/podcasts-personal-stories.html',
#  'https://the-turing-way.netlify.app/communication/presentations.html',
#  'https://the-turing-way.netlify.app/communication/presentations/presentations-remote.html',
#  'https://the-turing-way.netlify.app/communication/presentations/presentations-personal-stories.html',
#  'https://the-turing-way.netlify.app/communication/social-media.html',
#  'https://the-turing-way.netlify.app/communication/social-media/social-media-twitter-tips.html',
#  'https://the-turing-way.netlify.app/communication/social-media/social-media-twitter-multiple.html',
#  'https://the-turing-way.netlify.app/communication/research-objects.html',
#  'https://the-turing-way.netlify.app/communication/research-objects/ro-concepts.html',
#  'https://the-turing-way.netlify.app/communication/research-objects/ro-implementation.html',
#  'https://the-turing-way.netlify.app/communication/citable.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-steps.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-cite.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-cff.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-cffinit.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-linking.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-orcid.html',
#  'https://the-turing-way.netlify.app/communication/citable/citable-resources.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles/data.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles/methods.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles/micro.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles/reg.html',
#  'https://the-turing-way.netlify.app/communication/dif-articles/software.html',
#  'https://the-turing-way.netlify.app/communication/os-comms.html',
#  'https://the-turing-way.netlify.app/communication/os-comms/os-comms-issue-tracking.html',
#  'https://the-turing-way.netlify.app/communication/os-comms/os-comms-channels.html',
#  'https://the-turing-way.netlify.app/communication/aa.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-overview.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-misconduct.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-traditions.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-equitable.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-tips.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-stories-interdisciplinary.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-stories-community.html',
#  'https://the-turing-way.netlify.app/communication/aa/aa-resources.html',
#  'https://the-turing-way.netlify.app/communication/peer-review.html',
#  'https://the-turing-way.netlify.app/communication/peer-review/peer-review-overview.html',
#  'https://the-turing-way.netlify.app/communication/peer-review/peer-review-open.html',
#  'https://the-turing-way.netlify.app/communication/peer-review/peer-review-guidance.html',
#  'https://the-turing-way.netlify.app/communication/peer-review/peer-review-code.html',
#  'https://the-turing-way.netlify.app/communication/peer-review/peer-review-resources.html',
#  'https://the-turing-way.netlify.app/communication/binder.html',
#  'https://the-turing-way.netlify.app/communication/binder/zero-to-binder.html',
#  'https://the-turing-way.netlify.app/collaboration/collaboration.html',
#  'https://the-turing-way.netlify.app/collaboration/github-novice.html',
#  'https://the-turing-way.netlify.app/collaboration/github-novice/github-novice-motivation.html',
#  'https://the-turing-way.netlify.app/collaboration/github-novice/github-novice-firststeps.html',
#  'https://the-turing-way.netlify.app/collaboration/github-novice/github-novice-features.html',
#  'https://the-turing-way.netlify.app/collaboration/github-novice/github-novice-advanced.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review/maintain-review-maintenance.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review/maintain-review-permissions.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review/maintain-review-review.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review/maintain-review-merge.html',
#  'https://the-turing-way.netlify.app/collaboration/maintain-review/maintain-review-resources.html',
#  'https://the-turing-way.netlify.app/collaboration/organising-meetings.html',
#  'https://the-turing-way.netlify.app/collaboration/coworking.html',
#  'https://the-turing-way.netlify.app/collaboration/organising-conference.html',
#  'https://the-turing-way.netlify.app/collaboration/chairing.html',
#  'https://the-turing-way.netlify.app/collaboration/event-participation.html',
#  'https://the-turing-way.netlify.app/collaboration/informal-chats.html',
#  'https://the-turing-way.netlify.app/collaboration/event-tools.html',
#  'https://the-turing-way.netlify.app/collaboration/stakeholder-engagement.html',
#  'https://the-turing-way.netlify.app/collaboration/new-community.html',
#  'https://the-turing-way.netlify.app/collaboration/new-community/new-community-guide.html',
#  'https://the-turing-way.netlify.app/collaboration/new-community/new-community-techissues.html',
#  'https://the-turing-way.netlify.app/collaboration/new-community/new-community-differences.html',
#  'https://the-turing-way.netlify.app/collaboration/new-community/new-community-teamwork.html',
#  'https://the-turing-way.netlify.app/collaboration/academic-industry.html',
#  'https://the-turing-way.netlify.app/collaboration/academic-industry/academic-industry-establish.html',
#  'https://the-turing-way.netlify.app/collaboration/academic-industry/academic-industry-community.html',
#  'https://the-turing-way.netlify.app/collaboration/academic-industry/academic-industry-personal-story.html',
#  'https://the-turing-way.netlify.app/collaboration/team-manual.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership/leadership-features.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership/leadership-building.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership/leadership-opportunities.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership/leadership-story-hackathon.html',
#  'https://the-turing-way.netlify.app/collaboration/leadership/leadership-story-data-librarian.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/community-manager.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/data-steward.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/data-steward-personal-story.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/data-wrangler.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/rse.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/rse-personal-story.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/ram.html',
#  'https://the-turing-way.netlify.app/collaboration/research-infrastructure-roles/research-infrastructure-developer.html',
#  'https://the-turing-way.netlify.app/collaboration/remote-collab.html',
#  'https://the-turing-way.netlify.app/collaboration/remote-collab/remote-collab-prosandcons.html',
#  'https://the-turing-way.netlify.app/collaboration/remote-collab/remote-collab-guidelines.html',
#  'https://the-turing-way.netlify.app/collaboration/remote-collab/remote-collab-team.html',
#  'https://the-turing-way.netlify.app/collaboration/remote-collab/remote-collab-useful-resources.html',
#  'https://the-turing-way.netlify.app/collaboration/hybrid-collab.html',
#  'https://the-turing-way.netlify.app/collaboration/hybrid-collab/hybrid-collab-challenges.html',
#  'https://the-turing-way.netlify.app/collaboration/hybrid-collab/hybrid-collab-guidelines.html',
#  'https://the-turing-way.netlify.app/collaboration/hybrid-collab/hybrid-collab-resources.html',
#  'https://the-turing-way.netlify.app/collaboration/shared-ownership.html',
#  'https://the-turing-way.netlify.app/collaboration/shared-ownership/shared-ownership-projects.html',
#  'https://the-turing-way.netlify.app/collaboration/shared-ownership/shared-ownership-models.html',
#  'https://the-turing-way.netlify.app/collaboration/shared-ownership/shared-ownership-challenges.html',
#  'https://the-turing-way.netlify.app/collaboration/shared-ownership/shared-ownership-defaults.html',
#  'https://the-turing-way.netlify.app/collaboration/oss-sustainability/oss-sustainability-challenges.html',
#  'https://the-turing-way.netlify.app/ethical-research/ethical-research.html',
#  'https://the-turing-way.netlify.app/ethical-research/ethics-intro.html',
#  'https://the-turing-way.netlify.app/ethical-research/ethics-committees.html',
#  'https://the-turing-way.netlify.app/ethical-research/preclinical-research.html',
#  'https://the-turing-way.netlify.app/ethical-research/law-policy.html',
#  'https://the-turing-way.netlify.app/ethical-research/law-policy/law-policy-ethics.html',
#  'https://the-turing-way.netlify.app/ethical-research/law-policy/law-policy-rights.html',
#  'https://the-turing-way.netlify.app/ethical-research/law-policy/law-policy-resources.html',
#  'https://the-turing-way.netlify.app/ethical-research/social-data.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism/activism-unionisation.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism/activism-whistleblowing.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism/activism-cultural-change.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism/activism-robodebt.html',
#  'https://the-turing-way.netlify.app/ethical-research/activism/activism-case-study-google.html',
#  'https://the-turing-way.netlify.app/ethical-research/internal-policy.html',
#  'https://the-turing-way.netlify.app/ethical-research/self-reflection.html',
#  'https://the-turing-way.netlify.app/ethical-research/self-reflection/sr-positionality.html',
#  'https://the-turing-way.netlify.app/ethical-research/self-reflection/sr-power.html',
#  'https://the-turing-way.netlify.app/ethical-research/self-reflection/sr-prompts.html',
#  'https://the-turing-way.netlify.app/ethical-research/self-reflection/sr-resources.html',
#  'https://the-turing-way.netlify.app/ethical-research/ethics-open-source-governance.html',
#  'https://the-turing-way.netlify.app/community-handbook/community-handbook.html',
#  'https://the-turing-way.netlify.app/community-handbook/coc.html',
#  'https://the-turing-way.netlify.app/community-handbook/coc/coc-details.html',
#  'https://the-turing-way.netlify.app/community-handbook/coc/coc-reporting.html',
#  'https://the-turing-way.netlify.app/community-handbook/coc/coc-enforcement.html',
#  'https://the-turing-way.netlify.app/community-handbook/coc/coc-acknowledgement.html',
#  'https://the-turing-way.netlify.app/community-handbook/style.html',
#  'https://the-turing-way.netlify.app/community-handbook/style/style-citing.html',
#  'https://the-turing-way.netlify.app/community-handbook/style/style-crossref.html',
#  'https://the-turing-way.netlify.app/community-handbook/style/style-figures.html',
#  'https://the-turing-way.netlify.app/community-handbook/style/style-more-styling.html',
#  'https://the-turing-way.netlify.app/community-handbook/style/style-custom-styling.html',
#  'https://the-turing-way.netlify.app/community-handbook/consistency.html',
#  'https://the-turing-way.netlify.app/community-handbook/consistency/consistency-formatting.html',
#  'https://the-turing-way.netlify.app/community-handbook/consistency/consistency-structure.html',
#  'https://the-turing-way.netlify.app/community-handbook/consistency/consistency-language.html',
#  'https://the-turing-way.netlify.app/community-handbook/local-build.html',
#  'https://the-turing-way.netlify.app/community-handbook/contributing.html',
#  'https://the-turing-way.netlify.app/community-handbook/contributing/contributing-templates.html',
#  'https://the-turing-way.netlify.app/community-handbook/contributing/contributing-workflow.html',
#  'https://the-turing-way.netlify.app/community-handbook/acknowledgement.html',
#  'https://the-turing-way.netlify.app/community-handbook/acknowledgement/acknowledgement-members.html',
#  'https://the-turing-way.netlify.app/community-handbook/acknowledgement/acknowledgement-record.html',
#  'https://the-turing-way.netlify.app/community-handbook/acknowledgement/acknowledgement-examples.html',
#  'https://the-turing-way.netlify.app/community-handbook/newsletters.html',
#  'https://the-turing-way.netlify.app/community-handbook/newsletters/newsletters-process.html',
#  'https://the-turing-way.netlify.app/community-handbook/newsletters/newsletters-style.html',
#  'https://the-turing-way.netlify.app/community-handbook/newsletters/newsletters-template.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-application.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-logistics.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-illustrator.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-selection.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-events.html',
#  'https://the-turing-way.netlify.app/community-handbook/bookdash/bookdash-after.html',
#  'https://the-turing-way.netlify.app/community-handbook/coworking.html',
#  'https://the-turing-way.netlify.app/community-handbook/coworking/coworking-motivation.html',
#  'https://the-turing-way.netlify.app/community-handbook/coworking/coworking-collabcafe.html',
#  'https://the-turing-way.netlify.app/community-handbook/coworking/coworking-weekly.html',
#  'https://the-turing-way.netlify.app/community-handbook/coworking/coworking-organisation.html',
#  'https://the-turing-way.netlify.app/community-handbook/fireside-chat.html',
#  'https://the-turing-way.netlify.app/community-handbook/fireside-chat/fireside-chat-checklist.html',
#  'https://the-turing-way.netlify.app/community-handbook/fireside-chat/fireside-chat-roles.html',
#  'https://the-turing-way.netlify.app/community-handbook/presenting.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-bookdash-index.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-bookdash-precall.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-bookdash-github.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-bookdash-notes.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-bookdash-feedback.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-coworking-collabcafe.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-coworking-weekly.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-newsletter-draft.html',
#  'https://the-turing-way.netlify.app/community-handbook/templates/template-fireside-chat.html',
#  'https://the-turing-way.netlify.app/community-handbook/translation.html',
#  'https://the-turing-way.netlify.app/community-handbook/translation/translation-localisation.html',
#  'https://the-turing-way.netlify.app/community-handbook/translation/translation-workflow.html',
#  'https://the-turing-way.netlify.app/community-handbook/translation/translation-getting-started.html',
#  'https://the-turing-way.netlify.app/community-handbook/translation/translation-hello-crowdin.html',
#  'https://the-turing-way.netlify.app/afterword/afterword.html',
#  'https://the-turing-way.netlify.app/afterword/legal-disclaimer.html',
#  'https://the-turing-way.netlify.app/afterword/glossary.html',
#  'https://the-turing-way.netlify.app/afterword/bibliography.html',
#  'https://the-turing-way.netlify.app/afterword/contributors-record.html']

# %%
len(urls_filtered_list)
# Out:
# 354

# %%
from PyPDF2 import PdfMerger, PdfReader
from pyhtml2pdf import converter

def download_file(download_url, filename):
    converter.convert(download_url, filename, print_options={"displayHeaderFooter": True})

# %%
mergedObject = PdfMerger()
for fileNumber in range(len(urls_filtered_list)):
    pdf_path = urls_filtered_list[fileNumber]
    file_str = str(fileNumber)+ '.pdf'

    download_file(pdf_path, file_str)
                
    mergedObject.append(PdfReader(file_str, 'rb'))

mergedObject.write("mergedfilesoutput.pdf")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17516\2946292405.py in <module>
#       4     file_str = str(fileNumber)+ '.pdf'
#       5
# ----> 6     download_file(pdf_path, file_str)
#       7
#       8     mergedObject.append(PdfReader(file_str, 'rb'))
#
# ~\AppData\Local\Temp\ipykernel_17516\65277814.py in download_file(download_url, filename)
#       3
#       4 def download_file(download_url, filename):
# ----> 5     converter.convert(download_url, filename, print_options={"displayHeaderFooter": True})
#
# ~\anaconda3\lib\site-packages\pyhtml2pdf\converter.py in convert(source, target, timeout, compress, power, install_driver, print_options)
#      34     """
#      35
# ---> 36     result = __get_pdf_from_html(
#      37         source, timeout, install_driver, print_options)
#      38
#
# ~\anaconda3\lib\site-packages\pyhtml2pdf\converter.py in __get_pdf_from_html(path, timeout, install_driver, print_options)
#      78         driver = webdriver.Chrome(options=webdriver_options)
#      79
# ---> 80     driver.get(path)
#      81
#      82     try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     447     def get(self, url: str) -> None:
#     448         """Loads a web page in the current browser session."""
# --> 449         self.execute(Command.GET, {"url": url})
#     450
#     451     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_CONNECTION_RESET
#   (Session info: headless chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00E58893+48451]
# 	(No symbol) [0x00DEB8A1]
# 	(No symbol) [0x00CF5058]
# 	(No symbol) [0x00CF1843]
# 	(No symbol) [0x00CE8AC5]
# 	(No symbol) [0x00CE9B2A]
# 	(No symbol) [0x00CE8E23]
# 	(No symbol) [0x00CE8175]
# 	(No symbol) [0x00CE810C]
# 	(No symbol) [0x00CE6D46]
# 	(No symbol) [0x00CE74A8]
# 	(No symbol) [0x00CF67F2]
# 	(No symbol) [0x00D4CA61]
# 	(No symbol) [0x00D3A2BC]
# 	(No symbol) [0x00D4C482]
# 	(No symbol) [0x00D3A0B6]
# 	(No symbol) [0x00D17E08]
# 	(No symbol) [0x00D18F2D]
# 	GetHandleVerifier [0x010B8E3A+2540266]
# 	GetHandleVerifier [0x010F8959+2801161]
# 	GetHandleVerifier [0x010F295C+2776588]
# 	GetHandleVerifier [0x00EE2280+612144]
# 	(No symbol) [0x00DF4F6C]
# 	(No symbol) [0x00DF11D8]
# 	(No symbol) [0x00DF12BB]
# 	(No symbol) [0x00DE4857]
# 	BaseThreadInitThunk [0x76747D59+25]
# 	RtlInitializeExceptionChain [0x7761B74B+107]
# 	RtlClearBits [0x7761B6CF+191]

# %%
# n = 60
# download_file(urls_filtered_list[n], str(n)+ '.pdf')

# %%
for fileNumber in range(317, len(urls_filtered_list)):
    pdf_path = urls_filtered_list[fileNumber]
    file_str = str(fileNumber)+ '.pdf'

    download_file(pdf_path, file_str)

# %%
mergedObject = PdfMerger()
for fileNumber in range(len(urls_filtered_list)):
    file_str = str(fileNumber)+ '.pdf'
                
    mergedObject.append(PdfReader(file_str, 'rb'))

mergedObject.write("mergedfilesoutput.pdf")
