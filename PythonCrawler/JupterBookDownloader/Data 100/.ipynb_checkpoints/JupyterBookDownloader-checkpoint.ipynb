# %%
# Crawl


import requests
from bs4 import BeautifulSoup

url = 'https://learningds.org/intro.html'

reqs = requests.get(url)

soup = BeautifulSoup(reqs.text, 'html.parser')

urls = []
for link in soup.find_all('a'):
    urls.append(link.get('href'))
urls
# Out:
# ['index.html',
#  'preface.html',
#  'ch/01/lifecycle_intro.html',
#  'ch/01/lifecycle_cycle.html',
#  'ch/01/lifecycle_map.html',
#  'ch/01/lifecycle_summary.html',
#  'ch/02/data_scope_intro.html',
#  'ch/02/data_scope_big_data_hubris.html',
#  'ch/02/data_scope_construct.html',
#  'ch/02/data_scope_protocols.html',
#  'ch/02/data_scope_natural.html',
#  'ch/02/data_scope_accuracy.html',
#  'ch/02/data_scope_summary.html',
#  'ch/03/theory_intro.html',
#  'ch/03/theory_urn.html',
#  'ch/03/theory_election.html',
#  'ch/03/theory_vaccine_efficacy.html',
#  'ch/03/theory_measurement_error.html',
#  'ch/03/theory_summary.html',
#  'ch/04/modeling_intro.html',
#  'ch/04/modeling_simple.html',
#  'ch/04/modeling_loss_functions.html',
#  'ch/04/modeling_summary.html',
#  'ch/05/bus_intro.html',
#  'ch/05/bus_scope.html',
#  'ch/05/bus_clean.html',
#  'ch/05/bus_eda.html',
#  'ch/05/bus_modeling.html',
#  'ch/05/bus_summary.html',
#  'ch/06/pandas_intro.html',
#  'ch/06/pandas_subsetting.html',
#  'ch/06/pandas_aggregating.html',
#  'ch/06/pandas_joining.html',
#  'ch/06/pandas_transforming.html',
#  'ch/06/pandas_other_reps.html',
#  'ch/06/pandas_summary.html',
#  'ch/07/sql_intro.html',
#  'ch/07/sql_subsetting.html',
#  'ch/07/sql_aggregating.html',
#  'ch/07/sql_joining.html',
#  'ch/07/sql_transforming.html',
#  'ch/07/sql_summary.html',
#  'ch/08/files_intro.html',
#  'ch/08/files_datasets.html',
#  'ch/08/files_formats.html',
#  'ch/08/files_encoding.html',
#  'ch/08/files_size.html',
#  'ch/08/files_command_line.html',
#  'ch/08/files_granularity.html',
#  'ch/08/files_summary.html',
#  'ch/09/wrangling_intro.html',
#  'ch/09/wrangling_co2.html',
#  'ch/09/wrangling_checks.html',
#  'ch/09/wrangling_missing.html',
#  'ch/09/wrangling_transformations.html',
#  'ch/09/wrangling_structure.html',
#  'ch/09/wrangling_restaurants.html',
#  'ch/09/wrangling_summary.html',
#  'ch/10/eda_intro.html',
#  'ch/10/eda_feature_types.html',
#  'ch/10/eda_distributions.html',
#  'ch/10/eda_relationships.html',
#  'ch/10/eda_multi.html',
#  'ch/10/eda_guidelines.html',
#  'ch/10/eda_example.html',
#  'ch/10/eda_summary.html',
#  'ch/11/viz_intro.html',
#  'ch/11/viz_scale.html',
#  'ch/11/viz_smoothing.html',
#  'ch/11/viz_comparisons.html',
#  'ch/11/viz_data_design.html',
#  'ch/11/viz_context.html',
#  'ch/11/viz_plotly.html',
#  'ch/11/viz_other_tools.html',
#  'ch/11/viz_summary.html',
#  'ch/12/pa_intro.html',
#  'ch/12/pa_scope.html',
#  'ch/12/pa_collocated.html',
#  'ch/12/pa_cleaning_aqs.html',
#  'ch/12/pa_cleaning_purpleair.html',
#  'ch/12/pa_eda.html',
#  'ch/12/pa_modeling.html',
#  'ch/12/pa_conclusion.html',
#  'ch/13/text_intro.html',
#  'ch/13/text_examples.html',
#  'ch/13/text_strings.html',
#  'ch/13/text_regex.html',
#  'ch/13/text_sotu.html',
#  'ch/13/text_summary.html',
#  'ch/14/web_intro.html',
#  'ch/14/web_netCDF.html',
#  'ch/14/web_json.html',
#  'ch/14/web_http.html',
#  'ch/14/web_rest.html',
#  'ch/14/web_html.html',
#  'ch/14/web_summary.html',
#  'ch/15/linear_intro.html',
#  'ch/15/linear_simple.html',
#  'ch/15/linear_pa.html',
#  'ch/15/linear_simple_fit.html',
#  'ch/15/linear_multi.html',
#  'ch/15/linear_multi_fit.html',
#  'ch/15/linear_case.html',
#  'ch/15/linear_feature_eng.html',
#  'ch/15/linear_categorical.html',
#  'ch/15/linear_summary.html',
#  'ch/16/ms_intro.html',
#  'ch/16/ms_overfitting.html',
#  'ch/16/ms_train_test.html',
#  'ch/16/ms_cv.html',
#  'ch/16/ms_regularization.html',
#  'ch/16/ms_risk.html',
#  'ch/16/ms_summary.html',
#  'ch/17/inf_pred_gen_intro.html',
#  'ch/17/inf_pred_gen_dist.html',
#  'ch/17/inf_pred_gen_HT.html',
#  'ch/17/inf_pred_gen_boot.html',
#  'ch/17/inf_pred_gen_CI.html',
#  'ch/17/inf_pred_gen_PI.html',
#  'ch/17/inf_pred_gen_prob.html',
#  'ch/17/inf_pred_gen_summary.html',
#  'ch/18/donkey_intro.html',
#  'ch/18/donkey_scope.html',
#  'ch/18/donkey_clean.html',
#  'ch/18/donkey_eda.html',
#  'ch/18/donkey_model.html',
#  'ch/18/donkey_summary.html',
#  'ch/19/class_intro.html',
#  'ch/19/class_example.html',
#  'ch/19/class_pred.html',
#  'ch/19/class_log_model.html',
#  'ch/19/class_loss.html',
#  'ch/19/class_dr.html',
#  'ch/19/class_summary.html',
#  'ch/20/gd_intro.html',
#  'ch/20/gd_basics.html',
#  'ch/20/gd_example.html',
#  'ch/20/gd_convex.html',
#  'ch/20/gd_alternative.html',
#  'ch/20/gd_summary.html',
#  'ch/21/fake_news_intro.html',
#  'ch/21/fake_news_question.html',
#  'ch/21/fake_news_data.html',
#  'ch/21/fake_news_exploring.html',
#  'ch/21/fake_news_modeling.html',
#  'ch/21/fake_news_summary.html',
#  'additional_resources.html',
#  'data_sources.html',
#  'ch/a01/prob_review.html',
#  'ch/a02/vector_space_review.html',
#  'ch/a04/ref_intro.html',
#  'ch/a04/ref_pandas.html',
#  'ch/a04/ref_seaborn.html',
#  'ch/a04/ref_matplotlib.html',
#  'ch/a04/ref_sklearn.html',
#  'ch/a11/contributors.html',
#  'references.html',
#  'https://jupyterbook.org',
#  '_sources/intro.md',
#  '#learning-data-science',
#  'http://www.samlau.me/',
#  'https://people.eecs.berkeley.edu/~jegonzal/',
#  'https://www.stat.berkeley.edu/~nolan/',
#  'preface.html',
#  'https://creativecommons.org/licenses/by-nc-nd/4.0/',
#  'preface.html']

# %%
import re
urls_filtered_list = []
for u in urls:
    for i in re.findall('.+html', str(u)):
        url_to_be_appended = "https://learningds.org/"+i
        if url_to_be_appended not in urls_filtered_list:
            print(i)
            urls_filtered_list.append(url_to_be_appended)
# Out:
# index.html
# preface.html
# ch/01/lifecycle_intro.html
# ch/01/lifecycle_cycle.html
# ch/01/lifecycle_map.html
# ch/01/lifecycle_summary.html
# ch/02/data_scope_intro.html
# ch/02/data_scope_big_data_hubris.html
# ch/02/data_scope_construct.html
# ch/02/data_scope_protocols.html
# ch/02/data_scope_natural.html
# ch/02/data_scope_accuracy.html
# ch/02/data_scope_summary.html
# ch/03/theory_intro.html
# ch/03/theory_urn.html
# ch/03/theory_election.html
# ch/03/theory_vaccine_efficacy.html
# ch/03/theory_measurement_error.html
# ch/03/theory_summary.html
# ch/04/modeling_intro.html
# ch/04/modeling_simple.html
# ch/04/modeling_loss_functions.html
# ch/04/modeling_summary.html
# ch/05/bus_intro.html
# ch/05/bus_scope.html
# ch/05/bus_clean.html
# ch/05/bus_eda.html
# ch/05/bus_modeling.html
# ch/05/bus_summary.html
# ch/06/pandas_intro.html
# ch/06/pandas_subsetting.html
# ch/06/pandas_aggregating.html
# ch/06/pandas_joining.html
# ch/06/pandas_transforming.html
# ch/06/pandas_other_reps.html
# ch/06/pandas_summary.html
# ch/07/sql_intro.html
# ch/07/sql_subsetting.html
# ch/07/sql_aggregating.html
# ch/07/sql_joining.html
# ch/07/sql_transforming.html
# ch/07/sql_summary.html
# ch/08/files_intro.html
# ch/08/files_datasets.html
# ch/08/files_formats.html
# ch/08/files_encoding.html
# ch/08/files_size.html
# ch/08/files_command_line.html
# ch/08/files_granularity.html
# ch/08/files_summary.html
# ch/09/wrangling_intro.html
# ch/09/wrangling_co2.html
# ch/09/wrangling_checks.html
# ch/09/wrangling_missing.html
# ch/09/wrangling_transformations.html
# ch/09/wrangling_structure.html
# ch/09/wrangling_restaurants.html
# ch/09/wrangling_summary.html
# ch/10/eda_intro.html
# ch/10/eda_feature_types.html
# ch/10/eda_distributions.html
# ch/10/eda_relationships.html
# ch/10/eda_multi.html
# ch/10/eda_guidelines.html
# ch/10/eda_example.html
# ch/10/eda_summary.html
# ch/11/viz_intro.html
# ch/11/viz_scale.html
# ch/11/viz_smoothing.html
# ch/11/viz_comparisons.html
# ch/11/viz_data_design.html
# ch/11/viz_context.html
# ch/11/viz_plotly.html
# ch/11/viz_other_tools.html
# ch/11/viz_summary.html
# ch/12/pa_intro.html
# ch/12/pa_scope.html
# ch/12/pa_collocated.html
# ch/12/pa_cleaning_aqs.html
# ch/12/pa_cleaning_purpleair.html
# ch/12/pa_eda.html
# ch/12/pa_modeling.html
# ch/12/pa_conclusion.html
# ch/13/text_intro.html
# ch/13/text_examples.html
# ch/13/text_strings.html
# ch/13/text_regex.html
# ch/13/text_sotu.html
# ch/13/text_summary.html
# ch/14/web_intro.html
# ch/14/web_netCDF.html
# ch/14/web_json.html
# ch/14/web_http.html
# ch/14/web_rest.html
# ch/14/web_html.html
# ch/14/web_summary.html
# ch/15/linear_intro.html
# ch/15/linear_simple.html
# ch/15/linear_pa.html
# ch/15/linear_simple_fit.html
# ch/15/linear_multi.html
# ch/15/linear_multi_fit.html
# ch/15/linear_case.html
# ch/15/linear_feature_eng.html
# ch/15/linear_categorical.html
# ch/15/linear_summary.html
# ch/16/ms_intro.html
# ch/16/ms_overfitting.html
# ch/16/ms_train_test.html
# ch/16/ms_cv.html
# ch/16/ms_regularization.html
# ch/16/ms_risk.html
# ch/16/ms_summary.html
# ch/17/inf_pred_gen_intro.html
# ch/17/inf_pred_gen_dist.html
# ch/17/inf_pred_gen_HT.html
# ch/17/inf_pred_gen_boot.html
# ch/17/inf_pred_gen_CI.html
# ch/17/inf_pred_gen_PI.html
# ch/17/inf_pred_gen_prob.html
# ch/17/inf_pred_gen_summary.html
# ch/18/donkey_intro.html
# ch/18/donkey_scope.html
# ch/18/donkey_clean.html
# ch/18/donkey_eda.html
# ch/18/donkey_model.html
# ch/18/donkey_summary.html
# ch/19/class_intro.html
# ch/19/class_example.html
# ch/19/class_pred.html
# ch/19/class_log_model.html
# ch/19/class_loss.html
# ch/19/class_dr.html
# ch/19/class_summary.html
# ch/20/gd_intro.html
# ch/20/gd_basics.html
# ch/20/gd_example.html
# ch/20/gd_convex.html
# ch/20/gd_alternative.html
# ch/20/gd_summary.html
# ch/21/fake_news_intro.html
# ch/21/fake_news_question.html
# ch/21/fake_news_data.html
# ch/21/fake_news_exploring.html
# ch/21/fake_news_modeling.html
# ch/21/fake_news_summary.html
# additional_resources.html
# data_sources.html
# ch/a01/prob_review.html
# ch/a02/vector_space_review.html
# ch/a04/ref_intro.html
# ch/a04/ref_pandas.html
# ch/a04/ref_seaborn.html
# ch/a04/ref_matplotlib.html
# ch/a04/ref_sklearn.html
# ch/a11/contributors.html
# references.html

# %%
urls_filtered_list
# Out:
# ['https://learningds.org/index.html',
#  'https://learningds.org/preface.html',
#  'https://learningds.org/ch/01/lifecycle_intro.html',
#  'https://learningds.org/ch/01/lifecycle_cycle.html',
#  'https://learningds.org/ch/01/lifecycle_map.html',
#  'https://learningds.org/ch/01/lifecycle_summary.html',
#  'https://learningds.org/ch/02/data_scope_intro.html',
#  'https://learningds.org/ch/02/data_scope_big_data_hubris.html',
#  'https://learningds.org/ch/02/data_scope_construct.html',
#  'https://learningds.org/ch/02/data_scope_protocols.html',
#  'https://learningds.org/ch/02/data_scope_natural.html',
#  'https://learningds.org/ch/02/data_scope_accuracy.html',
#  'https://learningds.org/ch/02/data_scope_summary.html',
#  'https://learningds.org/ch/03/theory_intro.html',
#  'https://learningds.org/ch/03/theory_urn.html',
#  'https://learningds.org/ch/03/theory_election.html',
#  'https://learningds.org/ch/03/theory_vaccine_efficacy.html',
#  'https://learningds.org/ch/03/theory_measurement_error.html',
#  'https://learningds.org/ch/03/theory_summary.html',
#  'https://learningds.org/ch/04/modeling_intro.html',
#  'https://learningds.org/ch/04/modeling_simple.html',
#  'https://learningds.org/ch/04/modeling_loss_functions.html',
#  'https://learningds.org/ch/04/modeling_summary.html',
#  'https://learningds.org/ch/05/bus_intro.html',
#  'https://learningds.org/ch/05/bus_scope.html',
#  'https://learningds.org/ch/05/bus_clean.html',
#  'https://learningds.org/ch/05/bus_eda.html',
#  'https://learningds.org/ch/05/bus_modeling.html',
#  'https://learningds.org/ch/05/bus_summary.html',
#  'https://learningds.org/ch/06/pandas_intro.html',
#  'https://learningds.org/ch/06/pandas_subsetting.html',
#  'https://learningds.org/ch/06/pandas_aggregating.html',
#  'https://learningds.org/ch/06/pandas_joining.html',
#  'https://learningds.org/ch/06/pandas_transforming.html',
#  'https://learningds.org/ch/06/pandas_other_reps.html',
#  'https://learningds.org/ch/06/pandas_summary.html',
#  'https://learningds.org/ch/07/sql_intro.html',
#  'https://learningds.org/ch/07/sql_subsetting.html',
#  'https://learningds.org/ch/07/sql_aggregating.html',
#  'https://learningds.org/ch/07/sql_joining.html',
#  'https://learningds.org/ch/07/sql_transforming.html',
#  'https://learningds.org/ch/07/sql_summary.html',
#  'https://learningds.org/ch/08/files_intro.html',
#  'https://learningds.org/ch/08/files_datasets.html',
#  'https://learningds.org/ch/08/files_formats.html',
#  'https://learningds.org/ch/08/files_encoding.html',
#  'https://learningds.org/ch/08/files_size.html',
#  'https://learningds.org/ch/08/files_command_line.html',
#  'https://learningds.org/ch/08/files_granularity.html',
#  'https://learningds.org/ch/08/files_summary.html',
#  'https://learningds.org/ch/09/wrangling_intro.html',
#  'https://learningds.org/ch/09/wrangling_co2.html',
#  'https://learningds.org/ch/09/wrangling_checks.html',
#  'https://learningds.org/ch/09/wrangling_missing.html',
#  'https://learningds.org/ch/09/wrangling_transformations.html',
#  'https://learningds.org/ch/09/wrangling_structure.html',
#  'https://learningds.org/ch/09/wrangling_restaurants.html',
#  'https://learningds.org/ch/09/wrangling_summary.html',
#  'https://learningds.org/ch/10/eda_intro.html',
#  'https://learningds.org/ch/10/eda_feature_types.html',
#  'https://learningds.org/ch/10/eda_distributions.html',
#  'https://learningds.org/ch/10/eda_relationships.html',
#  'https://learningds.org/ch/10/eda_multi.html',
#  'https://learningds.org/ch/10/eda_guidelines.html',
#  'https://learningds.org/ch/10/eda_example.html',
#  'https://learningds.org/ch/10/eda_summary.html',
#  'https://learningds.org/ch/11/viz_intro.html',
#  'https://learningds.org/ch/11/viz_scale.html',
#  'https://learningds.org/ch/11/viz_smoothing.html',
#  'https://learningds.org/ch/11/viz_comparisons.html',
#  'https://learningds.org/ch/11/viz_data_design.html',
#  'https://learningds.org/ch/11/viz_context.html',
#  'https://learningds.org/ch/11/viz_plotly.html',
#  'https://learningds.org/ch/11/viz_other_tools.html',
#  'https://learningds.org/ch/11/viz_summary.html',
#  'https://learningds.org/ch/12/pa_intro.html',
#  'https://learningds.org/ch/12/pa_scope.html',
#  'https://learningds.org/ch/12/pa_collocated.html',
#  'https://learningds.org/ch/12/pa_cleaning_aqs.html',
#  'https://learningds.org/ch/12/pa_cleaning_purpleair.html',
#  'https://learningds.org/ch/12/pa_eda.html',
#  'https://learningds.org/ch/12/pa_modeling.html',
#  'https://learningds.org/ch/12/pa_conclusion.html',
#  'https://learningds.org/ch/13/text_intro.html',
#  'https://learningds.org/ch/13/text_examples.html',
#  'https://learningds.org/ch/13/text_strings.html',
#  'https://learningds.org/ch/13/text_regex.html',
#  'https://learningds.org/ch/13/text_sotu.html',
#  'https://learningds.org/ch/13/text_summary.html',
#  'https://learningds.org/ch/14/web_intro.html',
#  'https://learningds.org/ch/14/web_netCDF.html',
#  'https://learningds.org/ch/14/web_json.html',
#  'https://learningds.org/ch/14/web_http.html',
#  'https://learningds.org/ch/14/web_rest.html',
#  'https://learningds.org/ch/14/web_html.html',
#  'https://learningds.org/ch/14/web_summary.html',
#  'https://learningds.org/ch/15/linear_intro.html',
#  'https://learningds.org/ch/15/linear_simple.html',
#  'https://learningds.org/ch/15/linear_pa.html',
#  'https://learningds.org/ch/15/linear_simple_fit.html',
#  'https://learningds.org/ch/15/linear_multi.html',
#  'https://learningds.org/ch/15/linear_multi_fit.html',
#  'https://learningds.org/ch/15/linear_case.html',
#  'https://learningds.org/ch/15/linear_feature_eng.html',
#  'https://learningds.org/ch/15/linear_categorical.html',
#  'https://learningds.org/ch/15/linear_summary.html',
#  'https://learningds.org/ch/16/ms_intro.html',
#  'https://learningds.org/ch/16/ms_overfitting.html',
#  'https://learningds.org/ch/16/ms_train_test.html',
#  'https://learningds.org/ch/16/ms_cv.html',
#  'https://learningds.org/ch/16/ms_regularization.html',
#  'https://learningds.org/ch/16/ms_risk.html',
#  'https://learningds.org/ch/16/ms_summary.html',
#  'https://learningds.org/ch/17/inf_pred_gen_intro.html',
#  'https://learningds.org/ch/17/inf_pred_gen_dist.html',
#  'https://learningds.org/ch/17/inf_pred_gen_HT.html',
#  'https://learningds.org/ch/17/inf_pred_gen_boot.html',
#  'https://learningds.org/ch/17/inf_pred_gen_CI.html',
#  'https://learningds.org/ch/17/inf_pred_gen_PI.html',
#  'https://learningds.org/ch/17/inf_pred_gen_prob.html',
#  'https://learningds.org/ch/17/inf_pred_gen_summary.html',
#  'https://learningds.org/ch/18/donkey_intro.html',
#  'https://learningds.org/ch/18/donkey_scope.html',
#  'https://learningds.org/ch/18/donkey_clean.html',
#  'https://learningds.org/ch/18/donkey_eda.html',
#  'https://learningds.org/ch/18/donkey_model.html',
#  'https://learningds.org/ch/18/donkey_summary.html',
#  'https://learningds.org/ch/19/class_intro.html',
#  'https://learningds.org/ch/19/class_example.html',
#  'https://learningds.org/ch/19/class_pred.html',
#  'https://learningds.org/ch/19/class_log_model.html',
#  'https://learningds.org/ch/19/class_loss.html',
#  'https://learningds.org/ch/19/class_dr.html',
#  'https://learningds.org/ch/19/class_summary.html',
#  'https://learningds.org/ch/20/gd_intro.html',
#  'https://learningds.org/ch/20/gd_basics.html',
#  'https://learningds.org/ch/20/gd_example.html',
#  'https://learningds.org/ch/20/gd_convex.html',
#  'https://learningds.org/ch/20/gd_alternative.html',
#  'https://learningds.org/ch/20/gd_summary.html',
#  'https://learningds.org/ch/21/fake_news_intro.html',
#  'https://learningds.org/ch/21/fake_news_question.html',
#  'https://learningds.org/ch/21/fake_news_data.html',
#  'https://learningds.org/ch/21/fake_news_exploring.html',
#  'https://learningds.org/ch/21/fake_news_modeling.html',
#  'https://learningds.org/ch/21/fake_news_summary.html',
#  'https://learningds.org/additional_resources.html',
#  'https://learningds.org/data_sources.html',
#  'https://learningds.org/ch/a01/prob_review.html',
#  'https://learningds.org/ch/a02/vector_space_review.html',
#  'https://learningds.org/ch/a04/ref_intro.html',
#  'https://learningds.org/ch/a04/ref_pandas.html',
#  'https://learningds.org/ch/a04/ref_seaborn.html',
#  'https://learningds.org/ch/a04/ref_matplotlib.html',
#  'https://learningds.org/ch/a04/ref_sklearn.html',
#  'https://learningds.org/ch/a11/contributors.html',
#  'https://learningds.org/references.html']

# %%
len(urls_filtered_list)
# Out:
# 157

# %%
from PyPDF2 import PdfMerger, PdfReader
from pyhtml2pdf import converter

def download_file(download_url, filename):
    converter.convert(download_url, filename, print_options={"displayHeaderFooter": True})

# %%
mergedObject = PdfMerger()
for fileNumber in range(len(urls_filtered_list)):
    pdf_path = urls_filtered_list[fileNumber]
    file_str = str(fileNumber)+ '.pdf'

    download_file(pdf_path, file_str)
                
    mergedObject.append(PdfReader(file_str, 'rb'))

mergedObject.write("mergedfilesoutput.pdf")

# %%
# n = 60
# download_file(urls_filtered_list[n], str(n)+ '.pdf')

# %%
for fileNumber in range(61, len(urls_filtered_list)):
    pdf_path = urls_filtered_list[fileNumber]
    file_str = str(fileNumber)+ '.pdf'

    download_file(pdf_path, file_str)
